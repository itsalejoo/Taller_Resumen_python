# %% [markdown]
# <a href="https://colab.research.google.com/github/itsalejoo/Taller_Resumen_python/blob/main/Taller_repaso_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##Importación de bibliotecas: Importamos las bibliotecas NumPy y Matplotlib para realizar cálculos numéricos y graficar, respectivamente.
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm

# Definición del sistema de ecuaciones: Definimos el sistema de ecuaciones como un arreglo numpy A para los coeficientes de las incógnitas y un arreglo B para los resultados de las ecuaciones.
A = np.array([[3, 9, -10], [1, -6, 4], [10, -2, 8]])
B = np.array([24, -4, 20])

# Resolución del sistema de ecuaciones: Utilizamos la función np.linalg.solve() de NumPy para encontrar la solución numérica del sistema de ecuaciones.
solution = np.linalg.solve(A, B)

# Impresión de la solución: Imprimimos los valores de las incógnitas (x, y, z) que resuelven el sistema de ecuaciones.
print("La solución del sistema de ecuaciones es:")
print("x =", solution[0])
print("y =", solution[1])
print("z =", solution[2])

#Graficación de las ecuaciones: Creamos una figura 3D y graficamos las superficies correspondientes a las ecuaciones del sistema.
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = np.linspace(-10, 10, 100) #un arreglo de números espaciados uniformemente en un intervalo específico. En este caso, el intervalo es de -10 a 10 (ambos inclusive), y se están generando 100 puntos equidistantes dentro de este rango.
y = np.linspace(-10, 10, 100)
X, Y = np.meshgrid(x, y)
Z1 = (-A[0,0]*X - A[0,1]*Y + B[0]) / A[0,2] #defino las coordenadas Z en función de X, Y
Z2 = (-A[1,0]*X - A[1,1]*Y + B[1]) / A[1,2]
Z3 = (-A[2,0]*X - A[2,1]*Y + B[2]) / A[2,2]


ax.plot_surface(X, Y, Z1, alpha=0.5) #trazando las lineas de las coordenadas X, Y, Z1
ax.plot_surface(X, Y, Z2, alpha=0.5)
ax.plot_surface(X, Y, Z3, alpha=0.5)
# Colores para las superficies
color_map_x = cm.Reds
color_map_y = cm.Greens
color_map_z = cm.Blues

surf1 = ax.plot_surface(X, Y, Z1, cmap=color_map_x, alpha=0.5) #Se aplica un esquema de color definido por color_map_z, y la superficie se traza con una transparencia de 0.5. El objeto surf3 guarda la referencia a esta superficie.
surf2 = ax.plot_surface(X, Y, Z2, cmap=color_map_y, alpha=0.5)
surf3 = ax.plot_surface(X, Y, Z3, cmap=color_map_z, alpha=0.5)
# Agregar una barra de color
fig.colorbar(surf1, ax=ax, shrink=0.5, aspect=5)

ax.set_xlabel('x') #establecen las etiquetas de los ejes x, y, y z respectivamente
ax.set_ylabel('y')
ax.set_zlabel('z')

ax.scatter(solution[0], solution[1], solution[2], color='black', s=100)  # Punto de intersección

#En resumen, este código resuelve un sistema de ecuaciones lineales, imprime la solución y grafica las ecuaciones en un espacio 3D. Las ecuaciones se grafican como superficies en función de x, y, z.
# Out:
# La solución del sistema de ecuaciones es:
# x = 2.990291262135922
# y = 0.40776699029126195
# z = -1.1359223300970875
